# %%
import re
import nltk
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords

nltk.download("punkt_tab", quiet=True) 
nltk.download("stopwords", quiet=True) 

text = "Hello World! Year 2026" 

print("Original Text:") 
print(text) 
print("-" * 50) 

tokens = word_tokenize(text)
print("Tokens:") 
print(tokens)  
print("-" * 50)

stop_words = set(stopwords.words('english')) 
filtered_tokens = []

for word in tokens:

    word = word.lower() 

    if word.isalpha() and word not in stop_words:
        filtered_tokens.append(word)

print("Filtered tokens:")
print(filtered_tokens)

print("-" * 50) 
    
def is_english_script(text):
    
    pattern = re.compile(r'^[A-Za-z0-9\s.,!?\'-]+$')
    return bool(pattern.match(text))

if is_english_script(text): 
    print("Script Validation: Text is English (Latin script)") 
else:
    print("Script Validation: Text contains invalid script")
# Out:
# C:\Users\KUNAL SHETIYA\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Original Text:
# Hello World! Year 2026
# --------------------------------------------------
# Tokens:
# ['Hello', 'World', '!', 'Year', '2026']
# --------------------------------------------------
# Filtered tokens:
# ['hello', 'world', 'year']
# --------------------------------------------------
# Script Validation: Text is English (Latin script)
